# %% [markdown]
# # Kickstarter Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 1 Data Loading

# %%
# Load the datasets
df_2016 = pd.read_csv('ks-projects-201612.csv', encoding='utf-8')
df_2018 = pd.read_csv('ks-projects-201801.csv', encoding='utf-8')
# Out:
# C:\Users\lawre\AppData\Local\Temp\ipykernel_29068\726664510.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2016 = pd.read_csv('ks-projects-201612.csv', encoding='utf-8')

# %%
df_2016
# Out:
#                ID                                               name   \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000004038                                     Where is Hank?
# 2       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3       1000011046  Community Film Project: The Art of Neighborhoo...
# 4       1000014025                               Monarch Espresso Bar
# ...            ...                                                ...
# 323745   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 323746   999977640                                          The Tribe
# 323747   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 323748   999987933                           BioDefense Education Kit
# 323749   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#               category  main_category  currency         deadline   goal   \
# ...

# %%
df_2018
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# ## Step 2: Check for Missing Values

# %%
# Check for missing values in both datasets
missing_values_2016 = df_2016.isnull().sum()
missing_values_2018 = df_2018.isnull().sum()

# %%
print("2016 dataset")
missing_values_2016
# Out:
# 2016 dataset
# ID                     0
# name                   4
# category               5
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3790
# Unnamed: 13       323125
# Unnamed: 14       323738
# Unnamed: 15       323746
# Unnamed: 16       323749
# dtype: int64

# %%
# Remove 'Unnamed' columns
df_2016 = df_2016.loc[:, ~df_2016.columns.str.startswith('Unnamed')]

# %%
missing_values_2016
# Out:
# ID                     0
# name                   4
# category               5
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3790
# Unnamed: 13       323125
# Unnamed: 14       323738
# Unnamed: 15       323746
# Unnamed: 16       323749
# dtype: int64

# %%
print("2018 dataset")
missing_values_2018
# Out:
# 2018 dataset
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %% [markdown]
# ### Check for duplicate

# %%
# Check for duplicate rows in both datasets
duplicate_rows_2016 = df_2016.duplicated().sum()
duplicate_rows_2018 = df_2018.duplicated().sum()

# %%
duplicate_rows_2016, duplicate_rows_2018
# Out:
# (0, 0)

# %%
# Generate summary statistics for the 2016 dataset
summary_stats_2016 = df_2016.describe()

summary_stats_2016
# Out:
#                 ID
# count  3.237500e+05
# mean   1.074943e+09
# std    6.193352e+08
# min    5.971000e+03
# 25%    5.375802e+08
# 50%    1.075818e+09
# 75%    1.611070e+09
# max    2.147476e+09

# %%
# Generate summary statistics for all columns
summary_stats_2016_all = df_2016.describe(include='all')

# %%
summary_stats_2016
# Out:
#                 ID
# count  3.237500e+05
# mean   1.074943e+09
# std    6.193352e+08
# min    5.971000e+03
# 25%    5.375802e+08
# 50%    1.075818e+09
# 75%    1.611070e+09
# max    2.147476e+09

# %%
# Check data types of all columns
print(df_2016.dtypes)

# Generate summary statistics for all columns
summary_stats_2016_all = df_2016.describe(include='all')

print(summary_stats_2016_all)
# Out:
# ID                 int64
# name              object
# category          object
# main_category     object
# currency          object
# deadline          object
# goal              object
# launched          object
# pledged           object
# state             object
# backers           object
# country           object
# usd pledged       object
# dtype: object
#                  ID                      name        category  main_category   \
# count   3.237500e+05                    323746          323745         323750
# unique           NaN                    321574             770            120
# top              NaN  New EP/Music Development  Product Design   Film & Video
# freq             NaN                        41           17477          57679
# mean    1.074943e+09                       NaN             NaN            NaN
# std     6.193352e+08                       NaN             NaN            NaN
# ...

# %%
summary_stats_2016_all
# Out:
#                  ID                      name        category  main_category   \
# count   3.237500e+05                    323746          323745         323750
# unique           NaN                    321574             770            120
# top              NaN  New EP/Music Development  Product Design   Film & Video
# freq             NaN                        41           17477          57679
# mean    1.074943e+09                       NaN             NaN            NaN
# std     6.193352e+08                       NaN             NaN            NaN
# min     5.971000e+03                       NaN             NaN            NaN
# 25%     5.375802e+08                       NaN             NaN            NaN
# 50%     1.075818e+09                       NaN             NaN            NaN
# 75%     1.611070e+09                       NaN             NaN            NaN
# max     2.147476e+09                       NaN             NaN            NaN
#
# ...
